# %%
from osp_graphs.v1_db import session, Text, Field, Subfield

# %%
session.query(Field.name).all()
# Out:
# [('Agriculture'),
#  ('Anthropology'),
#  ('Architecture'),
#  ('Area and Ethnic Studies'),
#  ('Art'),
#  ('Astronomy and Astrophysics'),
#  ('Biology'),
#  ('Business'),
#  ('Chemistry'),
#  ('Civil Engineering'),
#  ('Classics'),
#  ('Computer Science'),
#  ('Dentistry'),
#  ('Earth Sciences'),
#  ('Economics'),
#  ('Education'),
#  ('Engineering'),
#  ('English'),
#  ('Family and Consumer Sciences'),
#  ('Food Services'),
#  ('Forestry'),
#  ('Health Administration'),
#  ('History'),
#  ('Kinesiology'),
#  ('Languages and Literature (Modern'),
#  ('Law'),
#  ('Library and Information Science'),
#  ('Linguistics'),
#  ('Maritime Professions'),
#  ('Media, Communications, Journalism'),
#  ('Medicine'),
#  ('Military Science'),
#  ('Nursing'),
#  ('Parks and Recreation'),
#  ('Performing Arts'),
#  ('Philosophy'),
#  ('Politics'),
#  ('Psychology'),
#  ('Public Affairs and Administration'),
#  ('Public Health'),
#  ('Public Safety'),
#  ('Religious Studies'),
#  ('Social Work'),
# ...

# %%
session.query(Subfield.name).all()
# Out:
# [('Agriculture'),
#  ('Agricultural Business'),
#  ('Agricultural Economics'),
#  ('Agronomy and Crop Science'),
#  ('Animal Science'),
#  ('Dairy Science'),
#  ('Soil Science'),
#  ('Food Science'),
#  ('Horticulture'),
#  ('Range Management'),
#  ('Anthropology'),
#  ('Archeology'),
#  ('Architecture'),
#  ('Interior Design'),
#  ('Environmental Design'),
#  ('Landscape Architecture'),
#  ('Urban Planning'),
#  ('Area, Ethnic, and Cultural Studies'),
#  ('Afro-American Studies'),
#  ('African Studies'),
#  ('American Studies'),
#  ('Asian Studies'),
#  ('East Asian Studies'),
#  ('European Studies'),
#  ('Latin American Studies'),
#  ('Near and Middle Eastern Studies'),
#  ('Native American Studies'),
#  ('Russian and Slavic Studies'),
#  ('Latino Studies'),
#  ('Pacific Area Studies'),
#  ('South Asian Studies'),
#  ('Southeast Asian Studies'),
#  ('Fine Arts and Art Studies'),
#  ('Art History, Criticism and Conservation'),
#  ('Commercial and Advertising Art'),
# ...
