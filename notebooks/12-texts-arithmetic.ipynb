# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import altair as alt
import pandas as pd

from scipy.sparse import lil_matrix
from annoy import AnnoyIndex
from collections import defaultdict
from titlecase import titlecase
from umap import UMAP

from sklearn.decomposition import TruncatedSVD
from sklearn import manifold
from sklearn.decomposition import PCA

from sqlalchemy.dialects.postgresql import array_agg
from sqlalchemy.sql import functions as func

from osp_graphs.v1_db import session, Text, Field, Subfield, SubfieldDocument, Citation, Document

# %%
count = func.count(Citation.text_id)

titles, surnames, text_doc_ids = zip(*session
    .query(Text.title, Text.surname, array_agg(Citation.document_id))
    .join(Citation)
    .filter(Text.valid==True)
    .filter(Text.display==True)
    .group_by(Text.id)
    .order_by(count.desc())
    .limit(2000)
    .all())

# %%
titles = [titlecase(t.strip(' /.,;')) for t in titles]

# %%
surnames = [s.strip(' /.,;').capitalize() for s in surnames]

# %%
doc_ids = list(set([did for doc_ids in text_doc_ids for did in doc_ids]))
doc_id_to_idx = {did: i for i, did in enumerate(doc_ids)}

# %%
M = lil_matrix((len(doc_ids), len(surnames)))

for sidx, doc_ids in enumerate(text_doc_ids):
    for did in doc_ids:
        didx = doc_id_to_idx[did]
        M[didx, sidx] += 1

# %%
M.sum()
# Out:
# 787921.0

# %%
svd = TruncatedSVD(n_components=10)

# %%
svd.fit(M)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=10, n_iter=5,
#        random_state=None, tol=0.0)

# %%
embedding = svd.components_.T

# %%
embedding.shape
# Out:
# (2000, 10)

# %%
idx = AnnoyIndex(10)
for i, v in enumerate(embedding):
    idx.add_item(i, v)
    
idx.build(10)
# Out:
# True

# %%
df = pd.DataFrame(list(zip(titles, surnames)), columns=('title', 'surname'))

# %%
df
# Out:
#                                                   title             surname
# 0                                 The Elements of Style              Strunk
# 1                                              Republic               Plato
# 2                               The Communist Manifesto                Marx
# 3                                               Biology            Campbell
# 4                                          Frankenstein             Shelley
# 5                                                Ethics           Aristotle
# 6                                             Leviathan              Hobbes
# 7                                            The Prince         Machiavelli
# 8                                               Oedipus           Sophocles
# 9                                                Hamlet         Shakespeare
# 10                                          The Odyssey               Homer
# 11                                          Orientalism                Said
# 12    A Manual for Writers of Term Papers, Theses, a...            Turabian
# 13                                            The Iliad               Homer
# 14                                    Heart of Darkness              Conrad
# 15                                     Canterbury Tales             Chaucer
# 16                                             Antigone           Sophocles
# 17                      Letter From the Birmingham Jail                King
# 18                                           On Liberty                Mill
# 19              The Structure of Scientific Revolutions                Kuhn
# 20                                        Paradise Lost              Milton
# 21                                       Utilitarianism                Mill
# 22                          The Clash of Civilizations?          Huntington
# 23                                    Things Fall Apart              Achebe
# 24                                              Apology               Plato
# 25                                                Power            Foucault
# 26                                    Origin of Species              Darwin
# 27                                          Confessions           Augustine
# 28                                         The Politics           Aristotle
# 29                A Manual for Writers of Dissertations            Turabian
# ...                                                 ...                 ...
# 1970  The Market for "Lemons": Quality Uncertainty a...             Akerlof
# 1971                                      Black & White             Shapiro
# 1972  Economic Action and Social Structure: The Prob...         Granovetter
# 1973                                           Durkheim             Giddens
# 1974                      Walden and Civil Disobedience             Thoreau
# 1975                           The Return of the Native               Hardy
# 1976  Unequal Childhoods : Class, Race, and Family Life              Lareau
# 1977                                 Television Culture               Fiske
# 1978                                The Blessed Damozel            Rossetti
# 1979                             Assessment of Children             Sattler
# 1980  Death Without Weeping : The Violence of Everyd...      Scheper-hughes
# 1981                              Microwave Engineering               Pozar
# 1982              The New Politics of the Welfare State             Pierson
# 1983                 The Origins of the First World War                Joll
# 1984                         Far From the Madding Crowd               Hardy
# 1985            Polyarchy; Participation and Opposition                Dahl
# 1986            English Grammar for Students of Spanish            Spinelli
# 1987  New and Old Wars : Organized Violence in a Glo...              Kaldor
# 1988  The Order of Things; An Archaeology of the Hum...            Foucault
# 1989  Asylums; Essays on the Social Situation of Men...             Goffman
# 1990         Songs of Innocence and Songs of Experience               Blake
# 1991                                           Calendar  University college
# 1992  Interpreting Qualitative Data : Methods for An...           Silverman
# 1993                            A Prayer for Owen Meany              Irving
# 1994     An Introduction to Theories of Popular Culture            Strinati
# 1995                                 American Diplomacy              Kennan
# 1996                                 The Golden Compass             Pullman
# 1997            Palestine and the Arab-Israeli Conflict               Smith
# 1998  Amusing Ourselves to Death : Public Discourse ...             Postman
# 1999                                 The Black Jacobins               James
#
# [2000 rows x 2 columns]

# %%
df[df.surname.str.contains('Marx')]
# Out:
#                                                   title surname
# 2                               The Communist Manifesto    Marx
# 43                                              Capital    Marx
# 157                                 The German Ideology    Marx
# 232                    Manifesto of the Communist Party    Marx
# 461                                   Selected Writings    Marx
# 1180       Economic and Philosophic Manuscripts of 1844    Marx
# 1335                          The Machine in the Garden    Marx
# 1455  A Contribution to the Critique of Political Ec...    Marx
# 1469                                            Kapital    Marx
# 1681                                     The Grundrisse    Marx
# 1792             Economic and Philosophical Manuscripts    Marx
# 1817                                     Early Writings    Marx

# %%
df[df.surname.str.contains('Milton')]
# Out:
#                          title surname
# 20               Paradise Lost  Milton
# 437     Paradise Lost : Book I  Milton
# 797               Areopagitica  Milton
# 976   Paradise Lost. Books 1-2  Milton
# 1563                   Lycidas  Milton

# %%
def nns_by_tid(tid, n=20):
    for tidx in idx.get_nns_by_item(tid, n):
        print(titles[tidx])

# %%
def nns_by_vector(v, n=20):
    for tidx in idx.get_nns_by_vector(v, n):
        print(titles[tidx])

# %%
nns_by_tid(43)
# Out:
# Capital
# The Grundrisse
# A Contribution to the Critique of Political Economy
# The German Ideology
# The Russian Revolution
# Suicide
# The Protestant Ethic and the Spirit of Capitalism
# Durkheim
# The Division of Labor in Society
# Unequal Childhoods : Class, Race, and Family Life
# The Elementary Forms of Religious Life
# Prison Notebooks
# From the 'Prison Notebooks'
# Economic and Philosophic Manuscripts of 1844
# Manifesto of the Communist Party
# The Russian Revolution
# Who Rules America?
# The Origin of the Family, Private Property and the State
# Karl Marx
# The Rules of Sociological Method

# %%
nns_by_tid(26)
# Out:
# Origin of Species
# The Descent of Man
# On the Origin of Species
# The Condition of the Working Class in England
# The Subjection of Women
# We Have Never Been Modern
# A Vindication of the Rights of Women
# The Rites of Passage
# Tristan and Isolde
# The Unconscious
# The Voyage of the Beagle
# The Interpretation of Dreams
# Britons : Forging the Nation, 1707-1837
# An Essay on the Principle of Population
# The Marriage of Figaro
# Kapital
# Traviata
# La Traviata
# Rights of Man
# An Essay on Population

# %%
nns_by_vector(np.mean([embedding[2], embedding[20]], 0))
# Out:
# On Population
# An Essay on Population
# An Essay on the Principle of Population
# Mein Kampf
# The Road to Wigan Pier
# Reflections on the Revolution in France
# The Economic Consequences of the Peace
# An Inquiry Into the Nature and Causes of the Wealth of Nations
# Wealth of Nations
# What Is to Be Done?
# The Revolution of 1905
# Stalin
# Imperialism
# A History of Western Society
# The Condition of the Working Class in England
# Kapital
# Lenin
# State and Revolution
# Principles of Political Economy
# The General Theory of Employment, Interest and Money

# %%
np.mean([embedding[24], embedding[26]], 0)
# Out:
# array([ 0.00700565,  0.07868603, -0.1062342 ,  0.00669924,  0.0181963 ,
#        -0.00912411, -0.01045703, -0.02161802,  0.08305466, -0.02000347])
